# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/dataset/skeletons/bay-gio-881_cropped.npy
# /kaggle/input/dataset/skeletons/hi-sinh-10563_cropped.npy
# /kaggle/input/dataset/skeletons/ho-dan-10818_cropped.npy
# /kaggle/input/dataset/skeletons/chai-nuoc-11662_cropped.npy
# /kaggle/input/dataset/skeletons/hoi-2680_cropped.npy
# /kaggle/input/dataset/skeletons/pha-2868_cropped.npy
# /kaggle/input/dataset/skeletons/thai-lan-3684_cropped.npy
# /kaggle/input/dataset/skeletons/xa-hoi-8064_cropped.npy
# /kaggle/input/dataset/skeletons/buoi-1863_cropped.npy
# /kaggle/input/dataset/skeletons/tap-the-4160_cropped.npy
# /kaggle/input/dataset/skeletons/rua-mat-9114_cropped.npy
# /kaggle/input/dataset/skeletons/tam-9038_cropped.npy
# /kaggle/input/dataset/skeletons/ban-chiu-2326_cropped.npy
# /kaggle/input/dataset/skeletons/chuc-mung-11865_cropped.npy
# /kaggle/input/dataset/skeletons/hop-thu-1356_cropped.npy
# /kaggle/input/dataset/skeletons/tau-thuy-9032_cropped.npy
# /kaggle/input/dataset/skeletons/the-he-8941_cropped.npy
# ...

# %%
# !git clone https://github.com/ToanPhamVan/vtv_sub.git
# Out:
# Cloning into 'vtv_sub'...
# remote: Enumerating objects: 7389, done.
# remote: Counting objects: 100% (2/2), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 7389 (delta 0), reused 1 (delta 0), pack-reused 7387
# Receiving objects: 100% (7389/7389), 747.82 MiB | 31.67 MiB/s, done.
# Resolving deltas: 100% (18/18), done.

# %%
cd /kaggle/working/vtv_sub
# Out:
# /kaggle/working/vtv_sub

# %%
cp -r /kaggle/input/dataset/skeletons /kaggle/working/vtv_sub

# %%
# !python gpu-train.py -i /kaggle/working/vtv_sub/skeletons -o /kaggle/working/vtv_sub/test_testmodel --start 1675 --end 2009
# Out:
# Training from 1675 to 2009
# Training: 100%|███████████████████████████████| 100/100 [00:41<00:00,  2.40it/s]
# Accuracy: 0.94375, Precision: 0.9464566929133859, Recall: 0.9405320813771518, F1 Score: 0.9434850863422293
# Training: 100%|███████████████████████████████| 100/100 [00:39<00:00,  2.51it/s]
# Accuracy: 0.99140625, Precision: 0.9835820895522388, Recall: 1.0, F1 Score: 0.9917231000752446
# Training: 100%|███████████████████████████████| 100/100 [00:38<00:00,  2.60it/s]
# Accuracy: 0.959375, Precision: 0.9794952681388013, Recall: 0.9409090909090909, F1 Score: 0.9598145285935085
# Training: 100%|███████████████████████████████| 100/100 [00:38<00:00,  2.59it/s]
# Accuracy: 0.9703125, Precision: 0.942684766214178, Recall: 1.0, F1 Score: 0.9704968944099379
# Training: 100%|███████████████████████████████| 100/100 [00:39<00:00,  2.55it/s]
# Accuracy: 0.98203125, Precision: 0.9639498432601881, Recall: 1.0, F1 Score: 0.9816440542697525
# ...

# %%
import shutil

shutil.make_archive('/kaggle/working/output/test_testmodel', 'zip', '/kaggle/working/vtv_sub/test_testmodel')
# Out:
# '/kaggle/working/output/test_testmodel.zip'
